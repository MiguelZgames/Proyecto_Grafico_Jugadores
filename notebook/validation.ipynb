# %%
import polars as pl

# %%
data = pl.read_csv(r"C:\Users\Miguel\Documents\Proyecto_Grafico_Jugadores\data\data-1761320956212.csv")
data2 = pl.read_parquet(r"C:\Users\Miguel\Documents\Proyecto_Grafico_Jugadores\data\data-1761320956212.parquet")
